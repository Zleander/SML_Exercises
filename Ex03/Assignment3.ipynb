# %% [markdown]
# # Assignment 3
# ## Due May 9th  at 12:00
#
# Please do not change any provided variable name. Read carefully the instructions in the exercise PDF and in this notebook. Add your solutions at `YOUR CODE HERE` and remove the corresponding `raise NotImplementedError()`.
# Before submitting: Please make sure, that your notebook can be executed from top to bottom without an error (Menu -> Kernel -> Restart & Run all).

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.optimize import minimize

# %% [markdown]
# ## Exercise 3

# %%
def get_data(n, seed=42):
    np.random.seed(seed)
    
    X = np.random.uniform(low=0, high=2, size=(n, 1))
    epsilon = np.random.normal(0, 2, (n, 1))
    y = 2 * np.sin(2 * X) + 0.1 * epsilon
    
    return X, y

# %%
xs, ys = get_data(100)
xs.shape, ys.shape
# Out:
# ((100, 1), (100, 1))

# %% [markdown]
# ### a)

# %%
# Create a new figure with new default axis
fig, axis = plt.subplots(1, 1)

# Plot here in axis
# YOUR CODE HERE
raise NotImplementedError()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb Cell 7' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000006?line=0'>1</a> # Create a new figure with new default axis
# ----> <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000006?line=1'>2</a> fig, axis = plt.subplots(1, 1)
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000006?line=3'>4</a> # Plot here in axis
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000006?line=4'>5</a> # YOUR CODE HERE
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000006?line=5'>6</a> raise NotImplementedError()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### b)

# %%
def ridge_regression(xs, ys, lam=1):
    # YOUR CODE HERE
    raise NotImplementedError()
    return w


def lasso_regression(xs, ys, lam=1):
    # Tip: You can use scipy.optimize.minimize
    # YOUR CODE HERE
    raise NotImplementedError()
    return w

# %% [markdown]
# ### c)

# %% [markdown]
# $\lambda = \{0.1, 1, 10\}$
#
# Ridge Regression:

# %%
lambdas = [0.1, 1, 10]
mse_per_lambda = [None, None, None]
ys_pred_per_lambda = [None, None, None]

for i, lam in enumerate(lambdas):
    # ridge regession
    # YOUR CODE HERE
    raise NotImplementedError()

    ys_pred_per_lambda[i] = ys_pred
    mse_per_lambda[i] = mse
    
print(mse_per_lambda)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb Cell 12' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000011?line=2'>3</a> ys_pred_per_lambda = [None, None, None]
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000011?line=4'>5</a> for i, lam in enumerate(lambdas):
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000011?line=5'>6</a>     # ridge regession
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000011?line=6'>7</a>     # YOUR CODE HERE
# ----> <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000011?line=7'>8</a>     raise NotImplementedError()
#      <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000011?line=9'>10</a>     ys_pred_per_lambda[i] = ys_pred
#      <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000011?line=10'>11</a>     mse_per_lambda[i] = mse
#
# NotImplementedError:

# %%
fig, axis = plt.subplots(1, 3)

for ax, ys_pred in zip(axis, ys_pred_per_lambda):
    plt.sca(ax)  # enable axis
    
    # First plot scatters, then the regression line
    # YOUR CODE HERE
    raise NotImplementedError()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb Cell 13' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000012?line=0'>1</a> fig, axis = plt.subplots(1, 3)
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000012?line=2'>3</a> for ax, ys_pred in zip(axis, ys_pred_per_lambda):
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000012?line=3'>4</a>     plt.sca(ax)  # enable axis
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Lasso Regression:

# %%
mse_per_lambda = [None, None, None]
ys_pred_per_lambda = [None, None, None]

for i, lam in enumerate(lambdas):
    # lasso regession
    # YOUR CODE HERE
    raise NotImplementedError()

    ys_pred_per_lambda[i] = ys_pred
    mse_per_lambda[i] = mse 
    
print(mse_per_lambda)


fig, axis = plt.subplots(1, 3)

for ax, ys_pred in zip(axis, ys_pred_per_lambda):
    plt.sca(ax)  # enable axis
    
    # First plot scatters, then the regression line
    # YOUR CODE HERE
    raise NotImplementedError()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb Cell 15' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000014?line=0'>1</a> mse_per_lambda = [None, None, None]
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000014?line=1'>2</a> ys_pred_per_lambda = [None, None, None]
# ----> <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000014?line=3'>4</a> for i, lam in enumerate(lambdas):
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000014?line=4'>5</a>     # lasso regession
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000014?line=5'>6</a>     # YOUR CODE HERE
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000014?line=6'>7</a>     raise NotImplementedError()
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000014?line=8'>9</a>     ys_pred_per_lambda[i] = ys_pred
#
# NameError: name 'lambdas' is not defined

# %% [markdown]
# ### d)

# %%
datasets = [(np.c_[xs, xs**2], ys) for xs, ys in
            (get_data(100, seed=seed) for seed in range(0, 100, 2))]

# Calculate the weights for ridge and lasso on all datasets.
# YOUR CODE HERE
raise NotImplementedError()

fig, axis = plt.subplots(1, 1)
# Scatter plot the absolute weight values
# use logarithmic axis scales and 
# set appropriate axis limits
# YOUR CODE HERE
raise NotImplementedError()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb Cell 17' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=0'>1</a> datasets = [(np.c_[xs, xs**2], ys) for xs, ys in
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=1'>2</a>             (get_data(100, seed=seed) for seed in range(0, 100, 2))]
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=3'>4</a> # Calculate the weights for ridge and lasso on all datasets.
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=4'>5</a> # YOUR CODE HERE
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=5'>6</a> raise NotImplementedError()
#
# /Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb Cell 17' in <listcomp>(.0)
# ----> <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=0'>1</a> datasets = [(np.c_[xs, xs**2], ys) for xs, ys in
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=1'>2</a>             (get_data(100, seed=seed) for seed in range(0, 100, 2))]
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=3'>4</a> # Calculate the weights for ridge and lasso on all datasets.
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=4'>5</a> # YOUR CODE HERE
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=5'>6</a> raise NotImplementedError()
#
# /Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb Cell 17' in <genexpr>(.0)
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=0'>1</a> datasets = [(np.c_[xs, xs**2], ys) for xs, ys in
# ----> <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=1'>2</a>             (get_data(100, seed=seed) for seed in range(0, 100, 2))]
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=3'>4</a> # Calculate the weights for ridge and lasso on all datasets.
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=4'>5</a> # YOUR CODE HERE
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000016?line=5'>6</a> raise NotImplementedError()
#
# NameError: name 'get_data' is not defined

# %% [markdown]
# ### e)

# %% [markdown]
# Ridge regression

# %%
# YOUR CODE HERE
raise NotImplementedError()

print(f'best lambda: {best_lambda}')
print(f'mse: {best_error}')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb Cell 20' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000019?line=0'>1</a> # YOUR CODE HERE
# ----> <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000019?line=1'>2</a> raise NotImplementedError()
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000019?line=3'>4</a> print(f'best lambda: {best_lambda}')
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000019?line=4'>5</a> print(f'mse: {best_error}')
#
# NotImplementedError:

# %%
fig, axis = plt.subplots(1, 1)

# Plot line of mse as a function of lambda
### BEGIN SOLUTION
pred = []
for i in lambdas:
    w = ridge_regression(Omega, ys, lam=i)
    ys_pred = Omega @ w
    pred.append(((ys - ys_pred) ** 2).mean())
plt.plot(lambdas, mse, marker='x')
### END SOLUTION
plt.xscale('log')

# %%
fig, axis = plt.subplots(1, 1)

# First plot scatters, then the regression line
# YOUR CODE HERE
raise NotImplementedError()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb Cell 21' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000020?line=0'>1</a> fig, axis = plt.subplots(1, 1)
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000020?line=2'>3</a> # First plot scatters, then the regression line
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000020?line=3'>4</a> # YOUR CODE HERE
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000020?line=4'>5</a> raise NotImplementedError()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Linear regresion

# %%
# YOUR CODE HERE
raise NotImplementedError()

print(mse)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb Cell 24' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000022?line=0'>1</a> # YOUR CODE HERE
# ----> <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000022?line=1'>2</a> raise NotImplementedError()
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000022?line=3'>4</a> print(mse)
#
# NotImplementedError:

# %%
fig, axis = plt.subplots(1, 1)

# First plot scatters, then the regression line
# YOUR CODE HERE
raise NotImplementedError()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb Cell 24' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000023?line=0'>1</a> fig, axis = plt.subplots(1, 1)
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000023?line=2'>3</a> # First plot scatters, then the regression line
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000023?line=3'>4</a> # YOUR CODE HERE
#       <a href='vscode-notebook-cell:/Users/moritz/Documents/shared_lehre_vorlesungen/2022_machine_learning/sheet3/Assignment3.ipynb#ch0000023?line=4'>5</a> raise NotImplementedError()
#
# NameError: name 'plt' is not defined
